# %%
#importing necessary libraries
import selenium
import pandas as pd
from bs4 import BeautifulSoup
import time

#Importing requests
import requests
from selenium.webdriver.common.by import By
import time

# importing regex
import re

# Importing selenium webdriver
from selenium import webdriver

# Importing required Exceptions
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait

# %%
#Activating the chrome browser
driver1 = webdriver.Chrome("chromedriver.exe")
# Out:
# C:\Users\PINKI\AppData\Local\Temp\ipykernel_2216\1817300090.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver1 = webdriver.Chrome("chromedriver.exe")

# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
#getting  the  amazon page
driver1.get('https://www.amazon.in/')
#Giving input
search_item= input('Enter the product that has to be searched : ')
# Out:
# Enter the product that has to be searched : Laptop

# %%
#Scraping search bar Xpath and clicking on search icon
search_bar = driver1.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')   
search_bar.clear()                                               
search_bar.send_keys(search_item)
search_button = driver1.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search_button.click()

# %% [markdown]
# # 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product vertical has less than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by

# %%
#collecting all the Product URLS here
urls = []
for i in range(0,3):
    Page_urls=driver1.find_elements(By.XPATH,"//a[@class='a-link-normal s-no-outline']")#collecting urls of all the laptop
    for i in Page_urls:
        urls.append(i.get_attribute('href'))
        
    #next button 
    nxt_btn=driver1.find_element(By.XPATH,"//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']") 
    url=nxt_btn.get_attribute('href')
    driver1.get(url)
    time.sleep(2)

# %%
len(url)
# Out:
# 66

# %%
#Making empty lists and scraping the required spots
Product_name = []
Brand_name= []
Price = []
Return = []
Expected_Delivery = []
Availability = []

#Start with for loop
for i in urls:
    driver1.get(i)
    time.sleep(2)
    
    
    #Scraping data for product name
    try:
        prod=driver1.find_element(By.XPATH,"//span[@id='productTitle']")
        Product_name.append(prod.text)
    except NoSuchElementException as e:
        Product_name.append("-")
        
        
    #Scraping data for brand name
    try:
        brand=driver1.find_element(By.XPATH,"//div[@id='bylineInfo_feature_div']/div/a")
        Brand_name.append(brand.text)
    except NoSuchElementException as e:
        Brand_name.append("-")
        
         #Scraping data for Price
    try:
        pri=driver1.find_element(By.XPATH,"//span[@id='priceblock_ourprice']")
        Price.append(pri.text)
    except NoSuchElementException as e:
        Price.append("-")
        
        
    #Scraping data for Return/Exchange
    try:
        ret=driver1.find_element(By.XPATH,"//div[@data-name='RETURNS_POLICY']/span/div[2]/a")
        Return.append(ret.text)
    except NoSuchElementException as e:
        Return.append("-")
        
     
    #Scraping data for Expected_Delivary
    try:
        delivary=driver1.find_element(By.XPATH,"//div[@id='ddmDeliveryMessage']/b")
        Expected_Delivery.append(delivary.text)
    except NoSuchElementException as e:
        Expected_Delivery.append("-")
        
        
    #Scraping data for Availability
    try:
        avai=driver1.find_element(By.XPATH,"//div[@id='availability']/span")
        Availability.append(avai.text)
    except NoSuchElementException as e:
        Availability.append("-")
        
# here  due   to code  rerunning  which  will take much  time   so   i am  removing the cell  output

# %%
Laptop=pd.DataFrame({})
Laptop['Name'] = Product_name
Laptop['Brand'] = Brand_name
Laptop['Return/exchange'] =Return
Laptop['Availability'] = Availability
Laptop['Expected_delievery']=Expected_Delivery
Laptop['Url']=urls
Laptop
# Out:
#    Name Brand Return/exchange Availability Expected_delievery  \
# 0     -     -               -            -                  -
# 1     -     -               -            -                  -
# 2     -     -               -            -                  -
# 3     -     -               -            -                  -
# 4     -     -               -            -                  -
# ..  ...   ...             ...          ...                ...
# 64    -     -               -            -                  -
# 65    -     -               -            -                  -
# 66    -     -               -            -                  -
# 67    -     -               -            -                  -
# 68    -     -               -            -                  -
#
#                                                   Url
# 0   https://www.amazon.in/gp/slredirect/picassoRed...
# 1   https://www.amazon.in/gp/slredirect/picassoRed...
# 2   https://www.amazon.in/HP-15-6-inch-Micro-Edge-...
# 3   https://www.amazon.in/Renewed-Dell-Latitude-La...
# 4   https://www.amazon.in/Lenovo-IdeaPad-Celeron-P...
# ..                                                ...
# 64  https://www.amazon.in/ASUS-14-0-inch-i5-1035G1...
# 65  https://www.amazon.in/HP-3-3250-Laptop-Windows...
# 66  https://www.amazon.in/Dell-i3-1115G4-35-56Cms-...
# 67  https://www.amazon.in/gp/slredirect/picassoRed...
# 68  https://www.amazon.in/gp/slredirect/picassoRed...
#
# [69 rows x 6 columns]

# %% [markdown]
# # 3 Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’,'guitar',;cakes'

# %%
#Activating the chrome browser with specified url
driver2 = webdriver.Chrome("chromedriver.exe")
# getting images.google.com
url = "https://images.google.com/"
#Creating empty list and giving search items as list and creating loop
urls = []    
data = []
search_item = ["fruits", "cars", "Machine Learning","guitar","cakes"]
for item in search_item:
    driver2.get(url)  
    time.sleep(5)
    search_bar = driver2.find_element(By.TAG_NAME,"input") #Xpath for search bar
    
    search_bar.send_keys(str(item))      #sending key word for search item
    
    search_button =driver2.find_element(By.XPATH,"//button[@class='Tg7LZd']").click() #Clicking on search button
    
    # scrolling the web page to get more images
    for _ in range(10):
        driver2.execute_script("window.scrollBy(0,1)")
        
        imgs = driver2.find_elements(By.XPATH,"//img[@class='rg_i Q4LuWd']")
    img_url = []
    for image in imgs:
        source = image.get_attribute('src')
        if source is not None:
                if(source[0:4] == 'http'):
                    img_url.append(source)
    for i in img_url[:10]:
        urls.append(i)
                    
for i in range(len(urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response = requests.get(urls[i])
    
file = open(r'C:\Users\PINKI\fliprobo_projects'+str(i)+".jpg", "wb")

file.write(response.content)
# Out:
# C:\Users\PINKI\AppData\Local\Temp\ipykernel_14004\3152244334.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver2 = webdriver.Chrome("chromedriver.exe")
# Downloading 0 of 10 images
# Downloading 1 of 10 images
# Downloading 2 of 10 images
# Downloading 3 of 10 images
# Downloading 4 of 10 images
# Downloading 5 of 10 images
# Downloading 6 of 10 images
# Downloading 7 of 10 images
# Downloading 8 of 10 images
# Downloading 9 of 10 images
# 8009

# %% [markdown]
# #  4::Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,“Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of thedetails is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
# Activating the chrome browser
item = input(" Enter the name of Smartphone that has to be searched : ")
driver4 = webdriver.Chrome("chromedriver.exe") 

#get the web page with given url
url = "https://www.flipkart.com/"
driver4.get(url)
time.sleep(3)
# Out:
#  Enter the name of Smartphone that has to be searched : Pixel
# C:\Users\PINKI\AppData\Local\Temp\ipykernel_2216\2294550697.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver4 = webdriver.Chrome("chromedriver.exe")

# %%
#giving input key word to search bar
serch_bar = driver4.find_element(By.XPATH,"//div[@class='_3OO5Xc']//input")
serch_bar.send_keys(item)

srch_btn = driver4.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
srch_btn.click()
time.sleep(5)

# %%
# Fetching urls of phones coming on 1st page
page1_urls = []
urls = driver4.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for url in urls:
    page1_urls.append(url.get_attribute("href"))

# %%
len(page1_urls)
# Out:
# 24

# %%
Smartphones = {}
Smartphones["Brand"] = []
Smartphones["Phone_name"] = []
Smartphones["Colour"] = []
Smartphones["RAM"] = []
Smartphones["Storage(ROM)"] = []
Smartphones["Primary_Camera"] = []
Smartphones["Secondary_Camera"] = []
Smartphones["Display_Size"] = []
Smartphones["Battery_Capacity"] = []
Smartphones["Price"] = []
Smartphones["URL"] = []
#  made  some  empty  list   for  the  future storage   of  scraped  data

# %%
# Scraping data from each url of page 1
for url in page1_urls:
    driver4.get(url)                                                        
    print("Scraping URL = ", url)
    Smartphones['URL'].append(url)                                                          
    time.sleep(2)
    
    
    #Clicking on read more button
    try:
        read_more = driver4.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')     
        read_more.click()
    except NoSuchElementException:
        print("Exception occured while moving to next page")
        
        
        #--------------------------------------------------------------------->>
    
    
    #Scraping brand name of phone data
    try:
        brand_tags = driver4.find_element(By.XPATH,'//span[@class="B_NuCI"]')      
        Smartphones["Brand"].append(brand_tags.text.split()[0])
    except NoSuchElementException:
        Smartphones['Brand'].append('-')
    
    
    #Scraping phone name data
    try:
        name_tags = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')     
        Smartphones['Phone_name'].append(name_tags.text)
    except NoSuchElementException:
        Smartphones['Phone_name'].append('-')
        
        
        #Scraping phone color data
    try:
        color_tags = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')      
        Smartphones['Colour'].append(color_tags.text)
    except NoSuchElementException:
        Smartphones['Colour'].append('-')
     
    
    #Scraping RAM data
    try:
        ram_tags = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[2]/td[2]/ul/li')                
        Smartphones['RAM'].append(ram_tags.text)
    except NoSuchElementException:
        Smartphones['RAM'].append('-')
    
    
    #Scraping ROM data
    try:
        rom_tags = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[1]/td[2]/ul/li')        
        Smartphones['Storage(ROM)'].append(rom_tags.text)
    except NoSuchElementException:
        Smartphones['Storage(ROM)'].append('-')
        
        
    #Scraping Primary camera data
    try:                                                                                    
        pri_tags = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[2]/td[2]/ul/li')
        Smartphones['Primary_Camera'].append(pri_tags.text)
    except NoSuchElementException:
        Smartphones['Primary_Camera'].append('-')
        
        
        #Scraping secondary camera data
    try:                                                                                    
        sec_tags = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[1]')
        if sec_tags != "Secondary_Camera" : 
            if driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[1]').text == "Secondary Camera":
                sec_cam = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[5]/td[2]/ul/li')
            else :
                raise NoSuchElementException
        else :
            sec_cam = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[6]/td[2]/ul/li')
        Smartphones['Secondary_Camera'].append(sec_cam.text)
    except NoSuchElementException:
        Smartphones['Secondary_Camera'].append('-')
     #Scraping Display size data 
    try:
        disp_tags = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/div')
        if disp_tags.text != "Display Features" : raise NoSuchElementException
        disp_size = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table[1]/tbody/tr[1]/td[2]/ul/li')  
        Smartphones['Display_Size'].append(disp_size.text)
    except NoSuchElementException:
        Smartphones['Display_Size'].append('-')
        
        #---------------------------------------->>>>>>>>>>>>>>>>>>>>>>>
        #Scraping battery capacity data
        
        
    try:
        if driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" :
            if driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
                bat_tags = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[1]')
                if bat_tags.text != "Battery_Capacity" : raise NoSuchElementException
                bat_capa = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[2]/ul/li')                
            elif driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :
                bat_tags = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[1]')
                if bat_tags.text != "Battery_Capacity" : raise NoSuchElementException
                bat_capa = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[2]/ul/li')
            else:
                raise NoSuchElementException
        else :
            bat_tags = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[1]')
            if bat_tags.text != "Battery_Capacity" : raise NoSuchElementException
            bat_capa = driver4.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[2]/ul/li')              
        Smartphones['Battery_Capacity'].append(bat_capa.text)
    except NoSuchElementException:
        Smartphones['Battery_Capacity'].append('-')
        
        
        
    #Scraping Price data
    try:
        price_tags = driver4.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')      
        Smartphones['Price'].append(price_tags.text)
    except NoSuchElementException:
        Smartphones['Price'].append('-')
# Out:
# Scraping URL =  https://www.flipkart.com/google-pixel-6a-charcoal-128-gb/p/itme5ae89135d44e?pid=MOBGFKX5YUXD74Z3&lid=LSTMOBGFKX5YUXD74Z3MXA2OB&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGFKX5YUXD74Z3.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/google-pixel-4a-just-black-128-gb/p/itm023b9677aa45d?pid=MOBFUSBNAZGY7HQU&lid=LSTMOBFUSBNAZGY7HQUWHTF0C&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBFUSBNAZGY7HQU.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/google-pixel-3a-clearly-white-64-gb/p/itmfgk4jfgstaack?pid=MOBFFGFPJSCEXMSG&lid=LSTMOBFFGFPJSCEXMSGODGRZE&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBFFGFPJSCEXMSG.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/realme-c30-bamboo-green-32-gb/p/itmfcf69b2db5059?pid=MOBGF37G7FRK8FBJ&lid=LSTMOBGF37G7FRK8FBJLNLFYW&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_4&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGF37G7FRK8FBJ.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/realme-c30-denim-black-32-gb/p/itmfcf69b2db5059?pid=MOBGF37G8TGKHFWJ&lid=LSTMOBGF37G8TGKHFWJIST95C&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGF37G8TGKHFWJ.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/realme-c30-lake-blue-32-gb/p/itmfcf69b2db5059?pid=MOBGF37GTRVMRJVK&lid=LSTMOBGF37GTRVMRJVKRYAJNG&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGF37GTRVMRJVK.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/realme-c30-denim-black-32-gb/p/itmfcf69b2db5059?pid=MOBGF37GMBMYRFBK&lid=LSTMOBGF37GMBMYRFBKNVTNSG&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_7&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGF37GMBMYRFBK.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm2a08ebbea3689?pid=MOBGDRHVKYHCVG7W&lid=LSTMOBGDRHVKYHCVG7WU0WEW8&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_8&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGDRHVKYHCVG7W.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm2a08ebbea3689?pid=MOBGDRHVHNBBBBP5&lid=LSTMOBGDRHVHNBBBBP57SXRTY&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_9&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGDRHVHNBBBBP5.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm2a08ebbea3689?pid=MOBGDRHVZN29ZJF4&lid=LSTMOBGDRHVZN29ZJF4QSKOSJ&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_10&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGDRHVZN29ZJF4.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-s21-fe-5g-olive-128-gb/p/itm76e6e65136e17?pid=MOBGCKMEMZE5UJXK&lid=LSTMOBGCKMEMZE5UJXK6LPNPI&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_11&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGCKMEMZE5UJXK.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/realme-c30-bamboo-green-32-gb/p/itmfcf69b2db5059?pid=MOBGF37GUWGZQYGR&lid=LSTMOBGF37GUWGZQYGRW97HI6&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_12&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGF37GUWGZQYGR.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/realme-c30-lake-blue-32-gb/p/itmfcf69b2db5059?pid=MOBGF37GWT4TGVZM&lid=LSTMOBGF37GWT4TGVZM1IFYZO&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGF37GWT4TGVZM.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/realme-c30-locked-airtel-prepaid-lake-blue-32-gb/p/itm938b2a52e171f?pid=MOBGFCFQZGEUXH35&lid=LSTMOBGFCFQZGEUXH35331CCP&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGFCFQZGEUXH35.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-ice-dawn-128-gb/p/itm2a08ebbea3689?pid=MOBGDRHVZ2F9AAM8&lid=LSTMOBGDRHVZ2F9AAM8DRR9FD&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGDRHVZ2F9AAM8.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-starry-sky-128-gb/p/itm2a08ebbea3689?pid=MOBGDRHVMW2UDXZY&lid=LSTMOBGDRHVMW2UDXZYRBYUFR&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGDRHVMW2UDXZY.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/samsung-galaxy-s21-fe-5g-graphite-128-gb/p/itm7be0f72fff180?pid=MOBGBPFZSPRG8GSU&lid=LSTMOBGBPFZSPRG8GSUYZCRY0&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGBPFZSPRG8GSU.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/realme-c30-locked-airtel-prepaid-denim-black-32-gb/p/itm938b2a52e171f?pid=MOBGFCFQTSHGRPYA&lid=LSTMOBGFCFQTSHGRPYATV0I3W&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGFCFQTSHGRPYA.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/vivo-t1-44w-midnight-galaxy-128-gb/p/itm2a08ebbea3689?pid=MOBGDRHVXFVCGS23&lid=LSTMOBGDRHVXFVCGS23RDLBPG&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGDRHVXFVCGS23.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-light-sea-green-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HQJZKSX3K&lid=LSTMOBGDC6HQJZKSX3KUVADVY&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGDC6HQJZKSX3K.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-heart-ocean-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HN5VTU6RR&lid=LSTMOBGDC6HN5VTU6RRUSMZV8&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGDC6HN5VTU6RR.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-starry-purple-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HFGCW5PGF&lid=LSTMOBGDC6HFGCW5PGFFKFQIM&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGDC6HFGCW5PGF.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/redmi-10-prime-phantom-black-128-gb/p/itm9377b4c936baa?pid=MOBG6RGPPXQFYJ4R&lid=LSTMOBG6RGPPXQFYJ4RW9POLT&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBG6RGPPXQFYJ4R.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede
# Scraping URL =  https://www.flipkart.com/infinix-smart-6-polar-black-64-gb/p/itmd4041ce33d262?pid=MOBGDC6HZHYVX96A&lid=LSTMOBGDC6HZHYVX96AHNLOZE&marketplace=FLIPKART&q=Pixel&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&iid=6a805262-238a-4cf0-8941-1663d211ecdd.MOBGDC6HZHYVX96A.SEARCH&ssid=nfmexav4hc0000001664247057096&qH=08822b3ae4e2aede

# %%
len(Smartphones['Brand'])
len(Smartphones['URL'])
len(Smartphones["Phone_name"])
len(Smartphones["Colour"])
len(Smartphones["RAM"])
len(Smartphones["Storage(ROM)"])
len(Smartphones["Primary_Camera"])
len(Smartphones["Secondary_Camera"])
len(Smartphones["Display_Size"])
len(Smartphones["Battery_Capacity"])
len(Smartphones["Price"])
len(Smartphones["URL"])
# Out:
# 24

# %%
df = pd.DataFrame(Smartphones)

# %%
df
# Out:
#       Brand        Phone_name           Colour   RAM Storage(ROM)  \
# 0    Google          Pixel 6a         Charcoal  6 GB       128 GB
# 1    Google          Pixel 4a       Just Black  6 GB       128 GB
# 2    Google          Pixel 3a    Clearly White  4 GB        64 GB
# 3    realme               C30     Bamboo Green  2 GB        32 GB
# 4    realme               C30      Denim Black  2 GB        32 GB
# 5    realme               C30        Lake Blue  2 GB        32 GB
# 6    realme               C30      Denim Black  3 GB        32 GB
# 7      vivo            T1 44W         Ice Dawn  4 GB       128 GB
# 8      vivo            T1 44W       Starry Sky  4 GB       128 GB
# 9      vivo            T1 44W  Midnight Galaxy  4 GB       128 GB
# 10  SAMSUNG  Galaxy S21 FE 5G            Olive  8 GB       128 GB
# 11   realme               C30     Bamboo Green  3 GB        32 GB
# 12   realme               C30        Lake Blue  3 GB        32 GB
# 13   Realme               C30        Lake Blue  2 GB        32 GB
# 14     vivo            T1 44W         Ice Dawn  6 GB       128 GB
# 15     vivo            T1 44W       Starry Sky  6 GB       128 GB
# 16  SAMSUNG  Galaxy S21 FE 5G         Graphite  8 GB       128 GB
# 17   Realme               C30      Denim Black  2 GB        32 GB
# 18     vivo            T1 44W  Midnight Galaxy  6 GB       128 GB
# 19  Infinix           Smart 6  Light Sea Green  2 GB        64 GB
# 20  Infinix           Smart 6   Heart Of Ocean  2 GB        64 GB
# 21  Infinix           Smart 6    Starry Purple  2 GB        64 GB
# 22    REDMI          10 Prime    Phantom Black  6 GB       128 GB
# 23  Infinix           Smart 6      Polar Black  2 GB        64 GB
#
#              Primary_Camera   Secondary_Camera          Display_Size  \
# 0             12.2MP + 12MP   8MP Front Camera   15.6 cm (6.14 inch)
# 1        12.2MP Rear Camera   8MP Front Camera  14.76 cm (5.81 inch)
# 2        12.2MP Rear Camera   8MP Front Camera   14.22 cm (5.6 inch)
# 3           8MP Rear Camera   5MP Front Camera   16.51 cm (6.5 inch)
# 4           8MP Rear Camera   5MP Front Camera   16.51 cm (6.5 inch)
# 5           8MP Rear Camera   5MP Front Camera   16.51 cm (6.5 inch)
# 6           8MP Rear Camera   5MP Front Camera   16.51 cm (6.5 inch)
# 7          50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 8          50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 9          50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 10  12MP + 12MP + 8MP (OIS)                  -   16.26 cm (6.4 inch)
# 11          8MP Rear Camera   5MP Front Camera   16.51 cm (6.5 inch)
# 12          8MP Rear Camera   5MP Front Camera   16.51 cm (6.5 inch)
# 13          8MP Rear Camera   5MP Front Camera   16.51 cm (6.5 inch)
# 14         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 15         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 16  12MP + 12MP + 8MP (OIS)                  -   16.26 cm (6.4 inch)
# 17          8MP Rear Camera   5MP Front Camera   16.51 cm (6.5 inch)
# 18         50MP + 2MP + 2MP  16MP Front Camera  16.36 cm (6.44 inch)
# 19        8 MP + Depth Lens   5MP Front Camera   16.76 cm (6.6 inch)
# 20        8 MP + Depth Lens   5MP Front Camera   16.76 cm (6.6 inch)
# 21        8 MP + Depth Lens   5MP Front Camera   16.76 cm (6.6 inch)
# 22   50MP + 8MP + 2MP + 2MP   8MP Front Camera   16.51 cm (6.5 inch)
# 23        8 MP + Depth Lens   5MP Front Camera   16.76 cm (6.6 inch)
#
#    Battery_Capacity    Price  \
# 0                 -  ₹34,199
# 1                 -  ₹31,999
# 2                 -  ₹39,999
# 3                 -   ₹6,110
# 4                 -   ₹6,110
# 5                 -   ₹6,110
# 6                 -   ₹6,499
# 7                 -  ₹13,499
# 8                 -  ₹13,499
# 9                 -  ₹13,499
# 10                -  ₹34,999
# 11                -   ₹6,499
# 12                -   ₹6,499
# 13                -   ₹5,360
# 14                -  ₹14,999
# 15                -  ₹14,999
# 16                -  ₹34,999
# 17                -   ₹5,360
# 18                -  ₹14,999
# 19                -   ₹6,499
# 20                -   ₹6,499
# 21                -   ₹6,499
# 22                -  ₹13,499
# 23                -   ₹6,499
#
#                                                   URL
# 0   https://www.flipkart.com/google-pixel-6a-charc...
# 1   https://www.flipkart.com/google-pixel-4a-just-...
# 2   https://www.flipkart.com/google-pixel-3a-clear...
# 3   https://www.flipkart.com/realme-c30-bamboo-gre...
# 4   https://www.flipkart.com/realme-c30-denim-blac...
# 5   https://www.flipkart.com/realme-c30-lake-blue-...
# 6   https://www.flipkart.com/realme-c30-denim-blac...
# 7   https://www.flipkart.com/vivo-t1-44w-ice-dawn-...
# 8   https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 9   https://www.flipkart.com/vivo-t1-44w-midnight-...
# 10  https://www.flipkart.com/samsung-galaxy-s21-fe...
# 11  https://www.flipkart.com/realme-c30-bamboo-gre...
# 12  https://www.flipkart.com/realme-c30-lake-blue-...
# 13  https://www.flipkart.com/realme-c30-locked-air...
# 14  https://www.flipkart.com/vivo-t1-44w-ice-dawn-...
# 15  https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 16  https://www.flipkart.com/samsung-galaxy-s21-fe...
# 17  https://www.flipkart.com/realme-c30-locked-air...
# 18  https://www.flipkart.com/vivo-t1-44w-midnight-...
# 19  https://www.flipkart.com/infinix-smart-6-light...
# 20  https://www.flipkart.com/infinix-smart-6-heart...
# 21  https://www.flipkart.com/infinix-smart-6-starr...
# 22  https://www.flipkart.com/redmi-10-prime-phanto...
# 23  https://www.flipkart.com/infinix-smart-6-polar...

# %%
df.to_csv("G:\\New folder\\newfile.csv")

# %% [markdown]
# # RESULTS HAVE BEEN SAVED IN CSV FILE

# %% [markdown]
# # 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
# Activating the chrome browser
driver5=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)

# opening google maps web page
url = "https://www.google.co.in/maps"
driver5.get(url)
time.sleep(2)
#Sending keyword for seach bar and search button
city = input('Enter City name that has to be searched : ')
search_bar = driver5.find_element(By.ID,"searchboxinput")                       
search_bar.clear()                                                             
time.sleep(2)

search_bar.send_keys(city)                                                     
search_btn = driver5.find_element(By.ID,"searchbox-searchbutton")              
search_btn.click()                                                             
time.sleep(3)

try:
    url_str = driver5.current_url
    print("URL Extracted: ", url_str)
    latitude_longitude = re.findall(r'@(.*)data',url_str)
    if len(latitude_longitude):
        lat_lng_list = latitude_longitude[0].split(",")
        if len(lat_lng_list)>=2:
            latitude = lat_lng_list[0]
            longitude = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(latitude, longitude))

except Exception as e:
        print("Error: ", str(e))
# Out:
# C:\Users\PINKI\AppData\Local\Temp\ipykernel_14004\1955446842.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver5=webdriver.Chrome("chromedriver.exe")
# Enter City name that has to be searched : Patna
# URL Extracted:  https://www.google.co.in/maps/place/Patna,+Bihar/@25.6082803,85.0029533,11z/data=!3m1!4b1!4m5!3m4!1s0x39f29937c52d4f05:0x831a0e05f607b270!8m2!3d25.5940947!4d85.1375645
# Latitude = 25.6082803, Longitude = 85.0029533

# %% [markdown]
# so here is latitude and longitude of patna

# %% [markdown]
# # 6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in.

# %%
driver=webdriver.Chrome("chromedriver.exe")
driver.get("https://trak.in/india-startup-funding-investment-2015/")
# Out:
# C:\Users\PINKI\AppData\Local\Temp\ipykernel_14004\3832913990.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")

# %%
Dates=[]
company=[]
Industry=[]
Investor_Name=[]
Investment_Type=[]
Amount=[]

# %%
#scraping the company name 
time.sleep(10)
companies=driver.find_elements(By.XPATH,"//td[@class='column-3']")
for i in companies:
    if len(company)>20:
            break
    else:
        if i.text is None :
            company.append("--") 
        else:
            company.append(i.text)
    
        

#scraping the Industry 
Ind=driver.find_elements(By.XPATH,"//td[@class='column-4']")
for i in Ind:
    if len(Industry)>20:
        break
    else :
        if i.text is None :
            Industry.append("--") 
        else:
            Industry.append(i.text)

#scraping the Dates 
dt=driver.find_elements(By.XPATH,"//td[@class='column-2']")
for i in dt:
    if len(Dates)>20 :
        break
    else:
        if i.text is None :
            Dates.append("--") 
        else:
            Dates.append(i.text)
            
#scraping the Investor_Name 
IN=driver.find_elements(By.XPATH,"//td[@class='column-7']")
for i in IN:
    if len(Investor_Name) >20:
        break
    else:
        if i.text is None :
            Investor_Name.append("--")
        else:
            Investor_Name.append(i.text)

#scraping the Investment_Type 
IT=driver.find_elements(By.XPATH,"//td[@class='column-8']")
for i in IT:
    if len(Investment_Type)>20:
        break
    else:
        if i.text is None :
            Investment_Type.append("--") 
        else:
            Investment_Type.append(i.text)

#scraping the Amount 
Price=driver.find_elements(By.XPATH,"//td[@class='column-9']")
for i in Price:
    if len(Amount)>20:
        break
    else:
        if i.text is None :
            Amount.append("--") 
        else:
            Amount.append(i.text)
            
df=pd.DataFrame([])
df['Company']=company
df['Industry']=Industry
df['Investor_Name']=Investor_Name
df['Amount Invested']=Amount
df['Specification']=Investment_Type
df['Dates']=Dates
df
# Out:
#         Company              Industry  \
# 0        BYJU’S              Edu-tech
# 1        Meesho            E-commerce
# 2        Swiggy  Online Food Delivery
# 3         Groww               FinTech
# 4       Beldara            E-commerce
# 5     DealShare            E-commerce
# 6      Uniphore            Technology
# 7         Dunzo            E-commerce
# 8        BYJU’S              Edu-tech
# 9   SkilloVilla              Edu-tech
# 10     CityMall            E-commerce
# 11        DotPe               FinTech
# 12     Doubtnut              Edu Tech
# 13       Zomato           Hospitality
# 14    Fingerlix           Hospitality
# 15        Zolve               FinTech
# 16    KreditBee               Finance
# 17    Pepperfry            E-commerce
# 18      Grofers            E-Commerce
# 19      Nothing            Technology
# 20  SplashLearn                EdTech
#
#                                         Investor_Name Amount Invested  \
# 0                                     Innoven Capital     460,000,000
# 1                              SoftBank Vision Fund 2     300,000,000
# 2   Amansa Holdings, Carmignac, Falcon Edge Capita...     343,000,000
# 3          MC Global Edtech, B Capital, Baron, others      83,000,000
# 4                            Hindustan Media Ventures       7,400,000
# 5                                     Innoven Capital     250,000,000
# 6                           Sorenson Capital Partners     140,000,000
# 7                           Krishtal Advisors Pte Ltd       8,000,000
# 8          MC Global Edtech, B Capital, Baron, others     460,000,000
# 9                               Titan Capital, others     300,000,000
# 10                                     Accel Partners      11,000,000
# 11                                               PayU      27,500,000
# 12  SIG Global, Sequoia Capital, WaterBridge Ventu...       2,500,000
# 13                                 Tiger Global, Kora     250,000,000
# 14           Rhodium Trust, Accel Partners and Swiggy    2,747,045.20
# 15     Accel Partners and Lightspeed Venture Partners     1,50,00,000
# 16  Azim Premji’s PremjiInvest and South Korea’s M...      75,000,000
# 17                                    InnoVen Capital       4,773,958
# 18                         SoftBank Vision Fund (SVF)      55,000,000
# 19                                                 GV      15,000,000
# 20                                       Owl Ventures      18,000,000
#
#      Specification       Dates
# 0         Series F  01/04/2021
# 1         Series E  05/04/2021
# 2         Series J  14/04/2021
# 3         Series D  07/04/2021
# 4          Venture  14/04/2021
# 5   Debt Financing  04/03/2021
# 6         Series D  31/03/2021
# 7         Series E  30/03/2021
# 8         Series F  30/03/2021
# 9             Seed  23/03/2021
# 10        Series A  25/03/2021
# 11        Series A  26/03/2021
# 12        Series B  11/02/2021
# 13         Venture  22/02/2021
# 14        Series C  19/02/2021
# 15            Seed  17/02/2021
# 16        Series C  15/02/2021
# 17  Debt Financing  12/02/2021
# 18     Unspecified  12/02/2021
# 19        Series A  09/02/2021
# 20        Series C  09/02/2021

# %% [markdown]
# # 7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)
# Out:
# C:\Users\PINKI\AppData\Local\Temp\ipykernel_14004\77493732.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")

# %%
#Opening the specified url
url = "https://www.digit.in/"
driver.get(url)
time.sleep(3)
#searching for best laptop
best_gam_lap = driver.find_element(By.XPATH,"//div[@class='listing_container']//ul//li[9]").click()
time.sleep(4)

# %%
#Creating empty lists
lap_name = []
ope_sys = []
display = []
processor = []
memory = []
weight = []
dimensions = []
graph_proc = []
price = []

# %%
# Scraping the data of laptop names
name_tags = driver.find_elements(By.XPATH,"//table[@id='summtable']//tr//td[1]")
for name in name_tags:
    lap_name.append(name.text)
    
    
#Scraping the data of operating system
try:
    os_tags = driver.find_elements(By.XPATH,"//div[@class='Spcs-details']//tr[3]//td[3]")
    for os in os_tags:
        ope_sys.append(os.text)
except NoSuchElementException:
    pass


#Scraping data of display
try:
    disp_tags = driver.find_elements(By.XPATH,"//div[@class='Spcs-details']//tr[4]//td[3]")
    for disp in disp_tags:
        display.append(disp.text)
except NoSuchElementException:
    pass


#Scraping data of Processor
try:
    pro_tags = driver.find_elements(By.XPATH,"//div[@class='Spcs-details']//tr[5]//td[3]")
    for pro in pro_tags:
        processor.append(pro.text)
except NoSuchElementException:
    pass

#Scraping data of memory
try:
    memo_tags = driver.find_elements(By.XPATH,"//div[@class='Spcs-details']//tr[6]//td[3]")
    for memo in memo_tags:
        memory.append(memo.text)
except NoSuchElementException:
    pass
#Scraping data of weight
try:
    wgt_tags = driver.find_elements(By.XPATH,"//div[@class='Spcs-details']//tr[7]//td[3]")
    for wgt in wgt_tags:
        weight.append(wgt.text)
except NoSuchElementException:
    pass


#Scraping data of dimensions
try:
    dim_tags = driver.find_elements(By.XPATH,"//div[@class='Spcs-details']//tr[8]//td[3]")
    for dim in dim_tags:
        dimensions.append(dim.text)
except NoSuchElementException:
    pass


#Scraping data of Graph processor
try:
    gra_tags = driver.find_elements(By.XPATH,"//div[@class='Spcs-details']//tr[9]//td[3]")
    for gra in gra_tags:
        graph_proc.append(gra.text)
except NoSuchElementException:
    pass
#Scraping data of price
try:
    pri_tags = driver.find_elements(By.XPATH,"//td[@class='smprice']")
    for pri in pri_tags:
        price.append(pri.text.replace('₹','Rs '))
except NoSuchElementException:
    pass

# %%
#DATA FRAMEING
Gaming_Laptop=pd.DataFrame({})
Gaming_Laptop['Laptop Name'] = lap_name
Gaming_Laptop['Operating system'] = ope_sys
Gaming_Laptop['Display'] = display
Gaming_Laptop['Processor'] = processor
Gaming_Laptop['Memory'] = memory
Gaming_Laptop['Weight'] = weight
Gaming_Laptop['Dimensions'] = dimensions
Gaming_Laptop['Price'] = price

# %%
Gaming_Laptop
# Out:
#                                       Laptop Name  \
# 0                            MSI Titan GT77-12UHS
# 1                                Alienware x17 R2
# 2           Acer Predator Triton 500 SE PT516-52s
# 3                         Omen by HP (16-B1371TX)
# 4   Acer Predator Helios 300 AN515-45 (NH.QBRSI.0
# 5                      MSI Delta 15 (A5EFK-083IN)
# 6                         Omen by HP (16-c0141AX)
# 7               Lenovo Legion 5i Pro (82RF00MGIN)
# 8   Alienware m15 R5 Ryzen Edition icc-c780001win
# 9                Lenovo Slim 7 Gen 6 (82K8002JIN)
# 10                           MSI Titan GT77-12UHS
# 11                               Alienware x17 R2
# 12          Acer Predator Triton 500 SE PT516-52s
# 13                        Omen by HP (16-B1371TX)
# 14  Acer Predator Helios 300 AN515-45 (NH.QBRSI.0
# 15                     MSI Delta 15 (A5EFK-083IN)
# 16                        Omen by HP (16-c0141AX)
# 17              Lenovo Legion 5i Pro (82RF00MGIN)
# 18  Alienware m15 R5 Ryzen Edition icc-c780001win
# 19               Lenovo Slim 7 Gen 6 (82K8002JIN)
#
#                                      Operating system  \
# 0    12th Gen Intel Core i9-12900HX 16 core processor
# 1   12th Gen Intel Core i9-12900H 14 core processo...
# 2   12th Gen Intel Core i7-12700H 14 core processo...
# 3   12th Gen Intel Core i7-12700H 14 core processo...
# 4                 AMD Ryzen 9-5900HX 8 core processor
# 5   AMD 5th Gen Ryzen 9-5900HX 8 core processor wi...
# 6   AMD Ryzen™ 9 5900HX 8 core processor with 3.3 ...
# 7   12th Gen Intel Core i7-12700H 14 core processo...
# 8   AMD Ryzen R7-5800H 8 core processor with 4.40 ...
# 9   Lenovo Ryzen 7-5800H processor with 3.2 GHz cl...
# 10   12th Gen Intel Core i9-12900HX 16 core processor
# 11  12th Gen Intel Core i9-12900H 14 core processo...
# 12  12th Gen Intel Core i7-12700H 14 core processo...
# 13  12th Gen Intel Core i7-12700H 14 core processo...
# 14                AMD Ryzen 9-5900HX 8 core processor
# 15  AMD 5th Gen Ryzen 9-5900HX 8 core processor wi...
# 16  AMD Ryzen™ 9 5900HX 8 core processor with 3.3 ...
# 17  12th Gen Intel Core i7-12700H 14 core processo...
# 18  AMD Ryzen R7-5800H 8 core processor with 4.40 ...
# 19  Lenovo Ryzen 7-5800H processor with 3.2 GHz cl...
#
#                                             Display        Processor  \
# 0   17.3″ (3840 x 2160) screen, 120 Hz refresh rate  Windows 11 Home
# 1   17.3″ (1920 x 1080) screen, 360 Hz refresh rate  Windows 11 Home
# 2     16″ (2560 x 1600) screen, 240 Hz refresh rate  Windows 11 Home
# 3                        16.1″ (2560 x 1440) screen  Windows 11 Home
# 4   15.6″ (2560 x 1440) screen, 165 Hz refresh rate  Windows 11 Home
# 5    15.6″ (1920 x 1080) screen, 240Hz refresh rate  Windows 11 Home
# 6                        16.1″ (2560 x 1440) screen  Windows 11 Home
# 7     16″ (2560 x 1600) screen, 165 Hz refresh rate  Windows 11 Home
# 8    15.6″ (1920 x 1080) screen, 165Hz refresh rate  Windows 11 Home
# 9                 15.6″ screen, 165 Hz refresh rate  Windows 11 Home
# 10  17.3″ (3840 x 2160) screen, 120 Hz refresh rate  Windows 11 Home
# 11  17.3″ (1920 x 1080) screen, 360 Hz refresh rate  Windows 11 Home
# 12    16″ (2560 x 1600) screen, 240 Hz refresh rate  Windows 11 Home
# 13                       16.1″ (2560 x 1440) screen  Windows 11 Home
# 14  15.6″ (2560 x 1440) screen, 165 Hz refresh rate  Windows 11 Home
# 15   15.6″ (1920 x 1080) screen, 240Hz refresh rate  Windows 11 Home
# 16                       16.1″ (2560 x 1440) screen  Windows 11 Home
# 17    16″ (2560 x 1600) screen, 165 Hz refresh rate  Windows 11 Home
# 18   15.6″ (1920 x 1080) screen, 165Hz refresh rate  Windows 11 Home
# 19                15.6″ screen, 165 Hz refresh rate  Windows 11 Home
#
#                          Memory  \
# 0     64 GB DDR5 RAM & 2 TB SSD
# 1     32 GB DDR5 RAM & 1 TB SSD
# 2     32 GB DDR5 RAM & 2 TB SSD
# 3      8 GB DDR5 RAM & 1 TB SSD
# 4   16 GB DDR4 RAM & 512 GB SSD
# 5     16 GB DDR4 RAM & 1 TB SSD
# 6    16 GB DDR4 RAM & 1 TB NVMe
# 7     16 GB DDR5 RAM & 1 TB SSD
# 8   16 GB DDR4 RAM & 512 GB SSD
# 9     16 GB DDR4 RAM & 1 TB SSD
# 10    64 GB DDR5 RAM & 2 TB SSD
# 11    32 GB DDR5 RAM & 1 TB SSD
# 12    32 GB DDR5 RAM & 2 TB SSD
# 13     8 GB DDR5 RAM & 1 TB SSD
# 14  16 GB DDR4 RAM & 512 GB SSD
# 15    16 GB DDR4 RAM & 1 TB SSD
# 16   16 GB DDR4 RAM & 1 TB NVMe
# 17    16 GB DDR5 RAM & 1 TB SSD
# 18  16 GB DDR4 RAM & 512 GB SSD
# 19    16 GB DDR4 RAM & 1 TB SSD
#
#                                                Weight  \
# 0   16 GB DDR6 NVIDIA GeForce RTX 3080 Ti Graphics...
# 1   16 GB DDR6 NVIDIA GEFORCE RTX 3080 Ti Graphics...
# 2   8 GB DDR6 NVIDIA GeForce RTXTM 3070 Ti Graphic...
# 3    8 GB GDDR6 NVIDIA GeForce RTX 3070 Graphics card
# 4     8 GB DDR6 NVIDIA GeForce RTX 3070 Graphics card
# 5        10 GB DDR6 AMD Radeon RX 6700M Graphics card
# 6       8 GB GDDR6 AMD Radeon™ RX 6600M Graphics card
# 7     6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 8     6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 9   6 GB DDR6 NVIDIA GeForce 3060 Max-Q Graphics card
# 10  16 GB DDR6 NVIDIA GeForce RTX 3080 Ti Graphics...
# 11  16 GB DDR6 NVIDIA GEFORCE RTX 3080 Ti Graphics...
# 12  8 GB DDR6 NVIDIA GeForce RTXTM 3070 Ti Graphic...
# 13   8 GB GDDR6 NVIDIA GeForce RTX 3070 Graphics card
# 14    8 GB DDR6 NVIDIA GeForce RTX 3070 Graphics card
# 15       10 GB DDR6 AMD Radeon RX 6700M Graphics card
# 16      8 GB GDDR6 AMD Radeon™ RX 6600M Graphics card
# 17    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 18    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card
# 19  6 GB DDR6 NVIDIA GeForce 3060 Max-Q Graphics card
#
#                                            Dimensions        Price
# 0         397 x 330 x 23 mm dimension & 3.3 kg weight          N/A
# 1        299 x 359 x 21 mm dimension & 2.96 kg weight  Rs  389,990
# 2       358 x 262 x 19.9 mm dimension & 2.4 kg weight  Rs  300,000
# 3        369 x 248 x 23 mm dimension & 2.32 kg weight  Rs  171,490
# 4       363 x 255 x 23.9 mm dimension & 2.4 kg weight  Rs  172,999
# 5         357 x 247 x 19 mm dimension & 1.9 kg weight  Rs  188,990
# 6     36.92 x 24.8 x 2.3 mm dimension & 2.3 kg weight  Rs  124,990
# 7        360 x 264 x 20 mm dimension & 2.49 kg weight  Rs  163,369
# 8   356.2 x 272.5 x 22.85 mm dimension & 2.69 kg w...  Rs  144,990
# 9         356 x 252 x 16 mm dimension & 1.9 kg weight  Rs  131,790
# 10        397 x 330 x 23 mm dimension & 3.3 kg weight          N/A
# 11       299 x 359 x 21 mm dimension & 2.96 kg weight  Rs  389,990
# 12      358 x 262 x 19.9 mm dimension & 2.4 kg weight  Rs  300,000
# 13       369 x 248 x 23 mm dimension & 2.32 kg weight  Rs  171,490
# 14      363 x 255 x 23.9 mm dimension & 2.4 kg weight  Rs  172,999
# 15        357 x 247 x 19 mm dimension & 1.9 kg weight  Rs  188,990
# 16    36.92 x 24.8 x 2.3 mm dimension & 2.3 kg weight  Rs  124,990
# 17       360 x 264 x 20 mm dimension & 2.49 kg weight  Rs  163,369
# 18  356.2 x 272.5 x 22.85 mm dimension & 2.69 kg w...  Rs  144,990
# 19        356 x 252 x 16 mm dimension & 1.9 kg weight  Rs  131,790

# %% [markdown]
# # Answer 8:: Write a python program to scrape the details for all billionaires from www.forbes.com. Details to bescrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver8 = webdriver.Chrome("chromedriver.exe")
url = "https://www.forbes.com/billionaires/"
driver8.get(url)
# Out:
# C:\Users\PINKI\AppData\Local\Temp\ipykernel_14004\1770317615.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver8 = webdriver.Chrome("chromedriver.exe")

# %%
#Scraping Rank
rank = []
Rank = driver8.find_elements(By.XPATH,"//div[@class='rank']")
for i in Rank:
    rank.append(i.text)

# %%
#Similarly for Name.net_worth,country and source

Name=[]
net_worth=[]
country=[]
source=[]
age=[]
industry=[]

# %%
name=driver8.find_elements(By.XPATH,"//div[@class='personName']")
for i in name:
    Name.append(i.text)
    
Net_worth=driver8.find_elements(By.XPATH,"//div[@class='netWorth']")
for i in Net_worth:
    net_worth.append(i.text)

Country=driver8.find_elements(By.XPATH,"//div[@class='countryOfCitizenship']")
for i in Country:
    country.append(i.text)
    
Source=driver8.find_elements(By.XPATH,"//div[@class='source']")
for i in Source:
    source.append(i.text)

# %%
import  warnings
warnings.filterwarnings('ignore')

#Scraping For Age
Age=driver8.find_elements(By.XPATH,"//div[@class='age']")
for i in Age:
    age.append(i.text)

# %%
#Scraping for Industry
Industry=driver8.find_elements(By.XPATH,"//div[@class='category']")
for i in Industry:
    industry.append(i.text)

# %%
df=pd.DataFrame({})
df['Rank']=rank
df['Name']=Name
df['Age']=age
df['Net Worth']=net_worth
df['Country']=country
df['Source']=source
df['Industry']=industry
df.head(10)
# Out:
#   Rank                      Name Age Net Worth        Country  \
# 0                      Elon Musk  50    $219 B  United States
# 1                     Jeff Bezos  58    $171 B  United States
# 2       Bernard Arnault & family  73    $158 B         France
# 3                     Bill Gates  66    $129 B  United States
# 4                 Warren Buffett  91    $118 B  United States
# 5                     Larry Page  49    $111 B  United States
# 6                    Sergey Brin  48    $107 B  United States
# 7                  Larry Ellison  77    $106 B  United States
# 8                  Steve Ballmer  66   $91.4 B  United States
# 9                  Mukesh Ambani  64   $90.7 B          India
#
#                Source               Industry
# 0       Tesla, SpaceX             Automotive
# 1              Amazon             Technology
# 2                LVMH       Fashion & Retail
# 3           Microsoft             Technology
# 4  Berkshire Hathaway  Finance & Investments
# 5              Google             Technology
# 6              Google             Technology
# 7            software             Technology
# 8           Microsoft             Technology
# 9         diversified            Diversified

# %% [markdown]
# # 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
url = input('Enter Youtube video URL:')
# Out:
# Enter Youtube video URL:https://www.youtube.com/watch?v=BvKmmTsC5Sk&t=424s

# %%
driver9 = webdriver.Chrome("chromedriver.exe")
driver9.get(url)

# %%
i=0
while(i<100):
    driver9.execute_script("window.scrollBy(0,500)") # scroll down to get more comments
    i+=1
while(i<402):
    driver9.execute_script("window.scrollBy(0,5000)") # scroll down to get more comments
    i+=1
#  here   we  are  using  the  method   of  scroll  down so  that  the  500  comments  can be  automated  then and  
# there

# %%
cmt = []
upvt = []
cmttime = []
#  creating  the  empty  list  for   the  storage

# %%
cmt_tag = driver9.find_elements(By.XPATH,"//*[@id='content-text']")
for i in cmt_tag:
    cmt.append(i.text.replace("\n",''))

upvt_tag = driver9.find_elements(By.XPATH,"//*[@id='vote-count-middle']")
for j in upvt_tag:
    try: 
        upvt.append(j.text)
    except:
        upvt.append('-')
cmttime_tag = driver9.find_elements(By.XPATH,"//*[@id='header-author']/yt-formatted-string/a")
for k in cmttime_tag:
    try: 
        cmttime.append(k.text)
    except:
        cmttime.append('-')

# %%
len(upvt)
# Out:
# 180

# %%
len(cmt)
# Out:
# 180

# %%
len(cmttime)
# Out:
# 180

# %%
for i in range(0,len(upvt)):
    if upvt[i] == '': 
        upvt[i] = '-' # replacing empty string with '-'

# %%
Youtube = {'Comment':cmt,'Commented':cmttime,'Number of upvotes':upvt}
YoutubeDF = pd.DataFrame(Youtube)
YoutubeDF
# Out:
#                                                Comment   Commented  \
# 0    हेमन्ता दादा, मैं UP से हूँ | और जितना सम्मान ...  8 days ago
# 1    आसाम के माननीय मुख्यमंत्री वर्तमान समय के चाणक...  4 days ago
# 2    You cannot beat CM of Assam in debate .He is o...  5 days ago
# 3    A GEM ️.... We need lots and lots of Humans li...  4 days ago
# 4    हेमंता जी आज की राजनीति के सुपरस्टार हैं।इनके ...  9 days ago
# ..                                                 ...         ...
# 175                                     My Fav Leader   3 days ago
# 176                                     Excellent Sir   8 days ago
# 177  अंजना जी ,आप सिर्फ एक छोटा सा न्यूज स्टूडियो च...  2 days ago
# 178  मै आज तक को धन्यवाद देना चाहता हु आपने बहुत सह...  5 days ago
# 179                                       This man on   8 days ago
#
#     Number of upvotes
# 0                 577
# 1                 131
# 2                 360
# 3                  35
# 4                 654
# ..                ...
# 175                 -
# 176                14
# 177                 2
# 178                10
# 179                11
#
# [180 rows x 3 columns]

# %% [markdown]
# # 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

# Opening the homepage of hostelworld.com
url = "https://www.hostelworld.com/"
driver.get(url)
# Out:
# C:\Users\PINKI\AppData\Local\Temp\ipykernel_2216\1120719205.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")

# %%
#Locating the location search bar
search_loc = driver.find_element(By.XPATH, '/html/body/div[3]/div/div/div[2]/div[1]/div/div/div[4]/div/div[2]/div/div[1]/div/div/div/input')
search_loc.send_keys("London")
time.sleep(2)

# %%
#Clicking on dropdown London
place = driver.find_element(By.XPATH, '//*[@id="predicted-search-results"]/li[2]')
place.click()
time.sleep(2)

#click in search button
search_btn = driver.find_element(By.ID, 'search-button')
search_btn.click()

# %%
#Creating empty lists
Hostel_Name = []
Distance = []
overall_review = []
total_reviews = []
facilities = []
price = []
Rating = []
property_description = []

# %%
while(True):
    
    # Hostel name
    names = driver.find_elements(By.XPATH, '//h2[@class="title title-6"]')
    for name in names:
        Hostel_Name.append(name.text)
    time.sleep(2)
        
    # Distance from city centre
    dis = driver.find_elements(By.XPATH, '//span[@class="description"]')
    for d in dis:
        Distance.append(d.text)
    time.sleep(2)
        
    # Overall Review    
    review = driver.find_elements(By.XPATH, '//div[@class="keyword"]//span')
    for r in review:
        overall_review.append(r.text)
    time.sleep(2)
    
    # Total No of reviews     
    t_review = driver.find_elements(By.XPATH, '//div[@class="reviews"]')
    for tr in t_review:
        total_reviews.append(tr.text)
    time.sleep(2)
    
    # facilities
    service = driver.find_elements(By.XPATH, '//div[@class="facilities-label facilities"]')
    for s in service:
        facilities.append(s.text)
    time.sleep(2)
    
    
     # Prices    
    prices = driver.find_elements(By.XPATH, '//div[@class="price-col"]')
    for p in prices:
        price.append(p.text)
    time.sleep(2)    
        
    try:
        next_button = driver.find_element(By.XPATH, '//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
        
time.sleep(4)        
        
#Separate  Privates_From price  and  Dorms_From price
Privates_From = []
for i in range(0,len(price),2):
    Privates_From.append(price[i])
time.sleep(2)

Dorms_From = []
for i in range(1,len(price),2):
    Dorms_From.append(price[i])

# %%
# scrape Hostels URL
hostel_url = []

while(True):
    urls = driver.find_elements(By.XPATH, '//h2[@class="title title-6"]//a')
    for url in urls:
        hostel_url.append(url.get_attribute("href"))
    time.sleep(2)    
        
    try:
        next_button = driver.find_element(By.XPATH, '//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break


        
Rate = []
for page in hostel_url:
    driver.get(page)
    
    # Rating
    try:
        ratings = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[1]/section/div[6]/div/div[1]/div[1]/div[1]')
        Rate.append(ratings.text)
    except NoSuchElementException:
        Rate.append("No Rating")  
    time.sleep(2)
    
 # Property Description
    try:
        pd = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[1]/section/div[6]/div/div[2]/div[2]/div/div[2]')
        property_description.append(pd.text)
    except NoSuchElementException:
        property_description.append("No Description")  

    
time.sleep(2)        
# remove extra data from Rating     
all_text = []
for i in Rate:
    all_text.append(i.split())
time.sleep(2)

for i in all_text:
    Rating.append(i[0])

# %%
Hostel_Name
# Out:
# ["St Christopher's Village",
#  'Urbany Hostel London',
#  'Safestay London Elephant & Castle',
#  'Hostel One Notting Hill',
#  "St Christopher's Hammersmith",
#  'NX London Hostel',
#  'Saint James Backpackers',
#  "St Christopher's Oasis-Female Only",
#  'Selina Camden',
#  'Britannia Inn Hotel',
#  'City Hotel Carlton',
#  'Elmwood Hotel',
#  'Kip Hotel',
#  'London House Hotel',
#  'TLK Apartments & Hotel',
#  'Colliers Hotel',
#  'Hotel Shepherds Bush London',
#  'Cranbrook Hotel',
#  'Hyde Park Court Hotel',
#  'Park Hotel Essex']

# %%
Distance
# Out:
# ['Hostel - 1.8km from city centre',
#  'Hostel - 5.4km from city centre',
#  'Hostel - 1.7km from city centre',
#  'Hostel - 5.5km from city centre',
#  'Hostel - 7.5km from city centre',
#  'Hostel - 6.1km from city centre',
#  'Hostel - 5.5km from city centre',
#  'Hostel - 1.8km from city centre',
#  'Hostel - 5.5km from city centre',
#  'Hotel - 14.5km from city centre',
#  'Hotel - 1.8km from city centre',
#  'Hotel - 3.2km from city centre',
#  'Hotel - 6.8km from city centre',
#  'Hotel - 5.3km from city centre',
#  'Hotel - 19.9km from city centre',
#  'Hotel - 2.1km from city centre',
#  'Hotel - 7.6km from city centre',
#  'Hotel - 14.8km from city centre',
#  'Hotel - 4.3km from city centre',
#  'Hotel - 24.1km from city centre']

# %%
total_reviews
# Out:
# ['11544 Total Reviews',
#  '477 Total Reviews',
#  '4529 Total Reviews',
#  '1506 Total Reviews',
#  '4121 Total Reviews',
#  '1232 Total Reviews',
#  '1828 Total Reviews',
#  '689 Total Reviews',
#  '36 Total Reviews',
#  '23 Total Reviews',
#  '45 Total Reviews',
#  '117 Total Reviews',
#  '54 Total Reviews',
#  '1382 Total Reviews',
#  '0 Total Reviews',
#  '8 Total Reviews',
#  '0 Total Reviews',
#  '58 Total Reviews',
#  '139 Total Reviews',
#  '109 Total Reviews']

# %%
overall_review
# Out:
# ['Fabulous',
#  'Fabulous',
#  'Fabulous',
#  'Superb',
#  'Good',
#  'Superb',
#  'Very Good',
#  'Very Good',
#  'Good',
#  'Fabulous',
#  'Fabulous',
#  'Fabulous',
#  'Very Good',
#  'Very Good',
#  'Good',
#  'Superb',
#  'No Rating',
#  'Good',
#  'No Rating',
#  'No Rating',
#  'Rating',
#  'Fabulous']

# %%
facilities
# Out:
# ['Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFree Breakfast',
#  'Free WiFi\nFree Breakfast\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free WiFi',
#  'Free Breakfast\nFollows Covid-19 sanitation guidance',
#  '',
#  '',
#  'Free WiFi',
#  'Free WiFi',
#  'Free WiFi',
#  'Follows Covid-19 sanitation guidance',
#  'Free WiFi\nFollows Covid-19 sanitation guidance',
#  'Free Breakfast\nFollows Covid-19 sanitation guidance',
#  'Free WiFi\nFree Breakfast',
#  'Free Breakfast\nFollows Covid-19 sanitation guidance']

# %%
price
# Out:
# ['No Privates Available',
#  'Dorms From\nRs4183.77 Rs3765',
#  'Privates From\nRs17799',
#  'No Dorms Available',
#  'No Privates Available',
#  'Dorms From\nRs3635',
#  'No Privates Available',
#  'Dorms From\nRs4448',
#  'No Privates Available',
#  'Dorms From\nRs4086.59 Rs3678',
#  'Privates From\nRs18307',
#  'No Dorms Available',
#  'Privates From\nRs12815',
#  'Dorms From\nRs6306',
#  'Privates From\nRs12870.3 Rs11583',
#  'No Dorms Available',
#  'No Privates Available',
#  'Dorms From\nRs8386.26 Rs7128',
#  'Privates From\nRs10025',
#  'No Dorms Available',
#  'Privates From\nRs25862',
#  'No Dorms Available',
#  'Privates From\nRs15982',
#  'No Dorms Available',
#  'Privates From\nRs11623',
#  'No Dorms Available',
#  'Privates From\nRs33345.8 Rs23342',
#  'No Dorms Available',
#  'Privates From\nRs8791',
#  'No Dorms Available',
#  'Privates From\nRs14877',
#  'No Dorms Available',
#  'Privates From\nRs29054.12 Rs23534',
#  'No Dorms Available',
#  'Privates From\nRs11623',
#  'No Dorms Available',
#  'Privates From\nRs15256',
#  'No Dorms Available',
#  'Privates From\nRs25136',
#  'No Dorms Available']

# %%
property_description
# Out:
# ['No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description',
#  'No Description']
